# %% [markdown]
# importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# storing csv in data variable

# %%
data= pd.read_csv("data.csv")

# %%
data
# Out:
#       Time Weather Temperature Company Humidity    Wind Goes
# 0  Morning   Sunny        Warm     Yes     Mild  Strong  Yes
# 1  Evening   Rainy        Cold      No     Mild  Normal   No
# 2  Morning   Sunny    Moderate     Yes   Normal  Normal  Yes
# 3  Evening   Sunny        Cold     Yes     High  Strong  Yes

# %% [markdown]
# representing in array form

# %%
d= np.array(data)[:,:-1]
print("The Attrinbutes are :",d)
# Out:
# The Attrinbutes are : [['Morning' 'Sunny' 'Warm' 'Yes' 'Mild' 'Strong']
#  ['Evening' 'Rainy' 'Cold' 'No' 'Mild' 'Normal']
#  ['Morning' 'Sunny' 'Moderate' 'Yes' 'Normal' 'Normal']
#  ['Evening' 'Sunny' 'Cold' 'Yes' 'High' 'Strong']]

# %% [markdown]
# Segretting the target that has positive and negative values

# %%
target= np.array(data)[:,-1]
print("the Target is :",target)
# Out:
# the Target is : ['Yes' 'No' 'Yes' 'Yes']

# %%
def train(c,t):
  for i, val in enumerate(t):
    if val == 'Yes':
      specific_hypothesis= c[i].copy()
      break

  for i, val in enumerate(c):
    if t[i]=="Yes":
      for x in range(len(specific_hypothesis)):
        if val[x] != specific_hypothesis[x]:
          specific_hypothesis[x] = '?'
        else:
          pass

  return specific_hypothesis

# %%
print("The Final Hypothesis :", train(d,target))
# Out:
# The Final Hypothesis : ['?' 'Sunny' '?' 'Yes' '?' '?']
